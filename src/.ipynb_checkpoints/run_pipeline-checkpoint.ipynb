# %%
import os
os.environ["PYSPARK_PYTHON"] = r"C:\Users\ranjan\Desktop\spark-olist-pipeline\venv\Scripts\python.exe"
os.environ["PYSPARK_DRIVER_PYTHON"] = r"C:\Users\ranjan\Desktop\spark-olist-pipeline\venv\Scripts\python.exe"
os.environ["spark.python.worker.reuse"] = "true"

# %%
import sys
sys.path.append(os.path.abspath("../src")) 
from bronze import create_spark_session, ingest_csv

spark = create_spark_session("OlistPipeline")

# %%
# Check AQE
print("Adaptive Query Execution Enabled:", spark.conf.get("spark.sql.adaptive.enabled"))
# Out:
# Adaptive Query Execution Enabled: true

# %%
# Define paths
base_input = "../data/"
base_output = "../../delta/bronze/"

# %%
# Bronze ingestion for all Olist tables
datasets = {
    "customers": "olist_customers_dataset.csv",
    "orders": "olist_orders_dataset.csv",
    "order_items": "olist_order_items_dataset.csv",
    "order_payments": "olist_order_payments_dataset.csv",
    "order_reviews": "olist_order_reviews_dataset.csv",
    "products": "olist_products_dataset.csv",
    "sellers": "olist_sellers_dataset.csv",
    "geolocation": "olist_geolocation_dataset.csv",
    "category_translation": "product_category_name_translation.csv"
}

# %%
for input_file, output_path, partition_col in datasets:
    print(f"[INFO] Ingesting {input_file} → {output_path}")

    if "orders" in input_file:  # partition only orders
        ingest_csv(spark, input_file, output_path, partition_col="order_purchase_month", target_file_rows=50000)
    else:
        ingest_csv(spark, input_file, output_path, target_file_rows=50000)

    df = spark.read.format("delta").load(output_path)
    print(f"[INFO] Showing table for {output_path}:")
    df.show(5, truncate=False)
# Out:
# [INFO] Ingesting ../data/olist_orders_dataset.csv → delta/bronze/orders
# [INFO] Added derived partition column 'order_purchase_month'
# [INFO] Ingested ../data/olist_orders_dataset.csv → delta/bronze/orders
# [INFO] Files written under delta/bronze/orders:
#    part-00000-10720bbd-fd53-4f96-b75a-7681dff75a41.c000.snappy.parquet → 0.00 MB
#    part-00001-95bf9905-d999-46e9-a601-1570c128bf7e.c000.snappy.parquet → 0.00 MB
#    part-00000-ce559434-a51c-420f-a79e-92376c360971.c000.snappy.parquet → 0.02 MB
#    part-00001-6f0e0fbf-3804-432d-a2b2-1e1721614728.c000.snappy.parquet → 0.02 MB
#    part-00000-567c5c4a-9888-4e36-b428-8c5b2ec48e24.c000.snappy.parquet → 0.00 MB
#    part-00000-f3219322-9cf1-40a3-ab71-f91751d92434.c000.snappy.parquet → 0.04 MB
#    part-00001-25101aac-a7ba-4d5d-931d-0d19b3aab8e1.c000.snappy.parquet → 0.04 MB
#    part-00000-22569943-53bf-448d-be65-964682fd0f15.c000.snappy.parquet → 0.09 MB
#    part-00001-4ada27c2-e368-4fb0-8611-38115fc989f3.c000.snappy.parquet → 0.09 MB
#    part-00000-0c5ae4b6-64b3-4618-ad9c-edc4adbd4e2b.c000.snappy.parquet → 0.14 MB
#    part-00001-10058516-ef9a-420f-abca-f5a78475123f.c000.snappy.parquet → 0.13 MB
#    part-00000-958c2675-a0af-4e1c-908b-0d4500efbe8c.c000.snappy.parquet → 0.12 MB
#    part-00001-44495473-0d71-4d0b-be0d-898edb97b01e.c000.snappy.parquet → 0.12 MB
#    part-00000-8d360e9b-1665-42e4-9899-0c592fd28ec3.c000.snappy.parquet → 0.18 MB
#    part-00001-4b0c782e-81e8-4210-8b56-a574969b8615.c000.snappy.parquet → 0.18 MB
#    part-00000-11894e30-a8d8-45c5-b9ea-083791611c90.c000.snappy.parquet → 0.00 MB
#    part-00001-de35113a-916a-47f5-9b43-7db98af9f5a3.c000.snappy.parquet → 0.00 MB
#    part-00000-3ac8b232-78c2-44b8-9eac-6293b2204153.c000.snappy.parquet → 0.00 MB
#    part-00001-43cd4f1c-1f22-4746-86c7-cb88291bb5fc.c000.snappy.parquet → 0.00 MB
# [INFO] Showing table for delta/bronze/orders:
# +--------------------------------+--------------------------------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+--------------------+
# |order_id                        |customer_id                     |order_status|order_purchase_timestamp|order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|order_purchase_month|
# +--------------------------------+--------------------------------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+--------------------+
# |0d3adebce4bebc1f80a7f36e9833f497|a7c87c25dbdded68c26c640582cb5ddb|canceled    |2018-09-03 18:40:50     |NULL             |NULL                        |NULL                         |2018-10-02 00:00:00          |2018-09             |
# |87ae60ef8b08ae0e5f903cacb53a6904|fea4d57ed3a45455f89c25ef3dae8ee8|canceled    |2018-09-11 16:45:54     |NULL             |NULL                        |NULL                         |2018-09-26 00:00:00          |2018-09             |
# |ea844c92cf978ea23321fa7fe5871761|6ddc45ad08e6a2c885ca2255fc52d6df|canceled    |2018-09-13 09:56:12     |NULL             |NULL                        |NULL                         |2018-09-27 00:00:00          |2018-09             |
# |ed3efbd3a87bea76c2812c66a0b32219|191984a8ba4cbb2145acb4fe35b69664|canceled    |2018-09-20 13:54:16     |NULL             |NULL                        |NULL                         |2018-10-17 00:00:00          |2018-09             |
# |4d59cc2a2e7bb6c0a851725f5888a9b5|ead83a4f8f7be8c3034b2e98754a6147|canceled    |2018-09-06 14:50:07     |NULL             |NULL                        |NULL                         |2018-09-21 00:00:00          |2018-09             |
# +--------------------------------+--------------------------------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+--------------------+
# only showing top 5 rows
#
# [INFO] Ingesting ../data/olist_customers_dataset.csv → delta/bronze/customers
# [INFO] Ingested ../data/olist_customers_dataset.csv → delta/bronze/customers
# [INFO] Files written under delta/bronze/customers:
#    part-00000-c9ceb87a-ddfa-47d1-894e-7ea8ba830c4e-c000.snappy.parquet → 3.36 MB
#    part-00001-43d017c8-2b7a-4a76-8f00-6f4f5171c956-c000.snappy.parquet → 3.35 MB
# [INFO] Showing table for delta/bronze/customers:
# +--------------------------------+--------------------------------+------------------------+-------------+--------------+
# |customer_id                     |customer_unique_id              |customer_zip_code_prefix|customer_city|customer_state|
# +--------------------------------+--------------------------------+------------------------+-------------+--------------+
# |15357da0aa538a1e5efabe63f0d71095|57f66dc16e5edbe9417e1e21c783b5a9|13010                   |campinas     |SP            |
# |47aa66905ec3df607310af4988d34bca|58aaf012cc88d1de4b976f45e059ddf5|4844                    |sao paulo    |SP            |
# |9015549e1e0438244f52123c59498fa6|e22c7e55a547f8d9bc30d2957ba1c9c5|45810                   |porto seguro |BA            |
# |9a12e00f66d6b5794f5825e62dc55a72|af9a735e918bd45a036e1a1a4cb67416|5821                    |sao paulo    |SP            |
# |16f5cb910633b2a0a8d93b9da0168381|e57af309c40f1e310fbf11e8374b0c32|9361                    |maua         |SP            |
# +--------------------------------+--------------------------------+------------------------+-------------+--------------+
# only showing top 5 rows
#
# [INFO] Ingesting ../data/olist_order_items_dataset.csv → delta/bronze/order_items
# [INFO] Ingested ../data/olist_order_items_dataset.csv → delta/bronze/order_items
# [INFO] Files written under delta/bronze/order_items:
#    part-00000-0a55717c-30b1-495e-8f1b-23f854510a2b-c000.snappy.parquet → 3.10 MB
#    part-00000-5f041b46-1c84-4ea8-9c82-ca4edef5e9c6-c001.snappy.parquet → 0.49 MB
#    part-00001-3585b0e0-a6c5-4fb3-b8e3-b845edcab11c-c001.snappy.parquet → 0.49 MB
#    part-00001-c23c3b8b-ecf0-4a58-a0d6-da716253dbd7-c000.snappy.parquet → 3.09 MB
# [INFO] Showing table for delta/bronze/order_items:
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+-----+-------------+
# |order_id                        |order_item_id|product_id                      |seller_id                       |shipping_limit_date|price|freight_value|
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+-----+-------------+
# |a9433e2f724570bead3613996a8857f7|1            |3f7b6fe5f870dc2ab126236c8f70e214|f27e33c6d29b5138fa9967bcd445b6d5|2017-11-30 23:31:28|59.9 |7.78         |
# |e7541d63acc69eb0bffae073a401b6ea|1            |d2f5484cbffe4ca766301b21ab9246dd|36a968b544695394e4e9d7572688598f|2018-06-15 12:19:20|12.88|7.87         |
# |a86139e0d4d95f37f763ce3060d04982|1            |ec43500eb99241b5278775e78a38dcea|3092c0b297aacfb4bb6e056ebe13b9b8|2018-03-19 22:48:11|129.9|42.79        |
# |c0e9ca196d5699995f7b3987a8931ebf|1            |114be868e131c0ec44f054b335118724|78c99c6dff4eeae5be99bf635ed21e3f|2017-05-12 13:10:19|30.0 |15.1         |
# |e2d9c66bdf5baf2058e9960542e386e2|1            |4a69baa66a13d1adeb41cfe3bc0c27be|bbad7e518d7af88a0897397ffdca1979|2018-02-08 12:50:29|99.9 |18.27        |
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+-----+-------------+
# only showing top 5 rows
#
# [INFO] Ingesting ../data/olist_sellers_dataset.csv → delta/bronze/sellers
# [INFO] Ingested ../data/olist_sellers_dataset.csv → delta/bronze/sellers
# [INFO] Files written under delta/bronze/sellers:
#    part-00000-14f4c523-ba1c-4c99-86bb-e3e257f1d9e3-c000.snappy.parquet → 0.06 MB
#    part-00001-a39b6b90-89f0-46b5-8fb9-1d207fb28fbd-c000.snappy.parquet → 0.06 MB
# [INFO] Showing table for delta/bronze/sellers:
# +--------------------------------+----------------------+--------------+------------+
# |seller_id                       |seller_zip_code_prefix|seller_city   |seller_state|
# +--------------------------------+----------------------+--------------+------------+
# |918f6fbcf3ab724d805867303e593a1b|13273                 |valinhos      |SP          |
# |1588ac4010787100dddef64568f0ae35|87045                 |maringa       |PR          |
# |06579cb253ecd5a3a12a9e6eb6bf8f47|4007                  |sao paulo - sp|SP          |
# |07bf9669d84d1f11be443a9dd938f698|4761                  |sao paulo     |SP          |
# |f1c1ac3f3efc07e659c035008e615e66|2119                  |sao paulo     |SP          |
# +--------------------------------+----------------------+--------------+------------+
# only showing top 5 rows
#
# [INFO] Ingesting ../data/olist_products_dataset.csv → delta/bronze/products
# [INFO] Ingested ../data/olist_products_dataset.csv → delta/bronze/products
# [INFO] Files written under delta/bronze/products:
#    part-00000-f177e58a-3993-4479-a5ec-c20ec1c140fd-c000.snappy.parquet → 0.66 MB
#    part-00001-7ce22cee-f54e-44d6-aab5-764cfaf917e0-c000.snappy.parquet → 0.66 MB
# [INFO] Showing table for delta/bronze/products:
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |product_id                      |product_category_name    |product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |aa5a3fa92cb1221a38267376d25cfd8a|cama_mesa_banho          |52                 |276                       |1                 |1150            |41               |13               |13              |
# |c7bd850b9a356ee44d5a2a55f7a5b657|esporte_lazer            |63                 |1562                      |10                |1150            |20               |16               |20              |
# |1953c4e517bc25739bc4223ede2ff5bc|relogios_presentes       |53                 |2390                      |1                 |800             |25               |14               |16              |
# |24fee4a800146a47846fa0e345b6d6ed|agro_industria_e_comercio|22                 |353                       |1                 |800             |20               |20               |20              |
# |269616df4c79febdae020f2d978594ed|climatizacao             |60                 |595                       |4                 |2400            |16               |40               |15              |
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# only showing top 5 rows
#
# [INFO] Ingesting ../data/olist
#    part-00012-714df4f8-b5a6-4693-a85f-6bd74eb8084d-c001.snappy.parquet → 0.00 MB
#    part-00013-6438fd54-e4f2-4428-b34e-811e2243acbf-c001.snappy.parquet → 0.00 MB
#    part-00013-eba29b4b-0e7a-4b70-9048-d57128e26262-c000.snappy.parquet → 1.02 MB
#    part-00014-4ebf6392-296e-4ecb-8808-d46e4141d9be-c001.snappy.parquet → 0.00 MB
#    part-00014-b04f78ca-0b1c-4d62-859f-938d1db2f7d6-c000.snappy.parquet → 1.01 MB
#    part-00015-83ae04f1-126a-454d-8724-ef054e502efe-c000.snappy.parquet → 1.01 MB
#    part-00015-eaf90d4b-5bab-4e69-aaff-8bdd0f18c23e-c001.snappy.parquet → 0.00 MB
#    part-00016-132f955f-8218-4467-8026-48e9c921a33e-c000.snappy.parquet → 1.02 MB
#    part-00016-7eb82006-a0e6-4183-92b5-004051e42e6c-c001.snappy.parquet → 0.00 MB
#    part-00017-04ce3358-580d-4940-af61-a17eec0c41d8-c001.snappy.parquet → 0.00 MB
#    part-00017-5882436d-f586-4d44-a973-388a1098b18c-c000.snappy.parquet → 1.02 MB
#    part-00018-7e11ccc8-3baa-425e-95c5-b323015dbbf3-c000.snappy.parquet → 1.01 MB
#    part-00018-a7b14837-772a-4084-b5f5-0ea1c83fcc01-c001.snappy.parquet → 0.00 MB
#    part-00019-a7b1b2a7-2389-4a76-a2ce-a6223b34ccb2-c000.snappy.parquet → 1.02 MB
#    part-00019-ace81b70-191e-4be2-9920-c909d2fa6910-c001.snappy.parquet → 0.00 MB
# [INFO] Showing table for delta/bronze/geolocation:
# +---------------------------+-------------------+-------------------+------------------+-----------------+
# |geolocation_zip_code_prefix|geolocation_lat    |geolocation_lng    |geolocation_city  |geolocation_state|
# +---------------------------+-------------------+-------------------+------------------+-----------------+
# |88330                      |-27.003944999999945|-48.621013999999974|balneario camboriu|SC               |
# |86450                      |-23.56868956691563 |-49.91627121192936 |quatiguá          |PR               |
# |97501                      |-29.75988059970312 |-57.098742723651746|uruguaiana        |RS               |
# |79820                      |-22.226070512308873|-54.82589114128071 |dourados          |MS               |
# |88960                      |-29.089903561887787|-49.611397102261385|sombrio           |SC               |
# +---------------------------+-------------------+-------------------+------------------+-----------------+
# only showing top 5 rows
#
# [INFO] Ingesting ../data/olist_order_payments_dataset.csv → delta/bronze/payments
# [INFO] Ingested ../data/olist_order_payments_dataset.csv → delta/bronze/payments
# [INFO] Files written under delta/bronze/payments:
#    part-00000-3265f49a-b315-436c-937d-b5a6c853a60d-c001.snappy.parquet → 0.07 MB
#    part-00000-f18bba0b-351f-47a3-b583-2a087d0688ae-c000.snappy.parquet → 1.79 MB
#    part-00001-4003e22f-a42d-483c-8492-52daabe49251-c001.snappy.parquet → 0.07 MB
#    part-00001-8da478df-3d99-4197-b4ee-953a4f1e6ccf-c000.snappy.parquet → 1.79 MB
# [INFO] Showing table for delta/bronze/payments:
# +--------------------------------+------------------+------------+--------------------+-------------+
# |order_id                        |payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------------------+------------------+------------+--------------------+-------------+
# |1fa8e437e5fc2d62dee8989fd5e8df97|1                 |credit_card |10                  |105.39       |
# |2a77e75a84066bc18c31a02f6b98dfca|1                 |credit_card |1                   |95.22        |
# |a4aecfaa64d23ee3758985066edde9c4|1                 |credit_card |3                   |95.4         |
# |a12de642288c88d6a5aec20f46a12fa6|1                 |credit_card |1                   |57.11        |
# |593f849c29daaeee17ee32baa44795d6|1                 |credit_card |10                  |1218.34      |
# +--------------------------------+------------------+------------+--------------------+-------------+
# only showing top 5 rows
#
# [INFO] Ingesting ../data/olist_order_reviews_dataset.csv → delta/bronze/reviews
# [INFO] Ingested ../data/olist_order_reviews_dataset.csv → delta/bronze/reviews
# [INFO] Files written under delta/bronze/reviews:
#    part-00000-48ed470d-346d-4bf9-a90b-2fb66f5ef17a-c001.snappy.parquet → 0.19 MB
#    part-00000-4ecfe418-4be3-4c16-a45b-fd6a33cf9aa3-c000.snappy.parquet → 4.44 MB
#    part-00001-808b88b0-9901-4ede-b7d0-e0f3d6e5e83b-c001.snappy.parquet → 0.19 MB
#    part-00001-a023c845-b099-4a18-bac8-bbdbec9cfc68-c000.snappy.parquet → 4.44 MB
# [INFO] Showing table for delta/bronze/reviews:
# +--------------------------------+--------------------------------+------------+--------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# |review_id                       |order_id                        |review_score|review_comment_title|review_comment_message                                                                                                                                          |review_creation_date|review_answer_timestamp|
# +--------------------------------+--------------------------------+------------+--------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# |1e644a660c6ebedd1432517632e1c005|8881dc280b8de23e6913aaee6bf61bb5|5           |ótimo               |Produto de excelente fabricação.                                                                                                                                |2018-06-16 00:00:00 |2018-06-18 11:37:37    |
# |47ff18d217d86cd7a9ddef80e7e090e4|fcc1d095fad4806c94b96c7bbe51188d|1           |Quantidade errada   |Comprei 10 e recebi somente 5.                                                                                                                                  |2018-08-10 00:00:00 |2018-08-17 20:09:34    |
# |b1eff16379510a352380e141d6d6fa93|fbe768ef510412dd02e7f6a28504ec7f|5           |NULL                |Empresa 100% Confiável. Agilidade na entrega ,e produto de alta qualidade, minha Esposa amou conj.Ap de Jantar porcelanato 20pcs Casambient. Parabéns targaryen |2017-12-30 00:00:00 |2017-12-30 19:46:38    |
# |7de18fb0f2eb445ec72afff2adf527af|f9e91772b7c00e703b2ef5657ec53ee1|5           |NULL                |NULL                                                                                                                                                            |2018-05-25 00:00:00 |2018-05-28 12:27:47    |
# |96b0aa5ecc991cc60c5ede5aab485e44|729bf6aed8c44bca10dba0fc98328fd0|4           |NULL                |NULL                                                                                                                                                            |2018-02-20 00:00:00 |2018-02-21 15:23:00    |
# +--------------------------------+--------------------------------+------------+--------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# only showing top 5 rows
#
# [INFO] Ingesting ../data/product_category_name_translation.csv → delta/bronze/category_translation
# [INFO] Ingested ../data/product_category_name_translation.csv → delta/bronze/category_translation
# [INFO] Files written under delta/bronze/category_translation:
#    part-00000-f734e889-12e5-4e8d-82e3-f88daf856633-c000.snappy.parquet → 0.00 MB
#    part-00001-01ed65fd-c1b9-4d94-981d-e963fef0eb4f-c000.snappy.parquet → 0.00 MB
# [INFO] Showing table for delta/bronze/category_translation:
# +-----------------------+-----------------------------+
# |product_category_name  |product_category_name_english|
# +-----------------------+-----------------------------+
# |esporte_lazer          |sports_leisure               |
# |seguros_e_servicos     |security_and_services        |
# |livros_interesse_geral |books_general_interest       |
# |sinalizacao_e_seguranca|signaling_and_security       |
# |ferramentas_jardim     |garden_tools                 |
# +-----------------------+-----------------------------+
# only showing top 5 rows

# %%
spark.stop()
print("Bronze layer ingestion completed successfully!")
# Out:
# Bronze layer ingestion completed successfully!
