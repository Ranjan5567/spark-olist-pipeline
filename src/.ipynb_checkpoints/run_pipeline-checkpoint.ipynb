# %%
import os
os.environ["PYSPARK_PYTHON"] = r"C:\Users\ranjan\Desktop\spark-olist-pipeline\venv\Scripts\python.exe"
os.environ["PYSPARK_DRIVER_PYTHON"] = r"C:\Users\ranjan\Desktop\spark-olist-pipeline\venv\Scripts\python.exe"
os.environ["spark.python.worker.reuse"] = "true"

# %%
import sys
sys.path.append(os.path.abspath("../src")) 
from bronze import create_spark_session, ingest_csv
from silver import curate_sales

spark = create_spark_session("OlistPipeline")

# %%
# Check AQE
print("Adaptive Query Execution Enabled:", spark.conf.get("spark.sql.adaptive.enabled"))
# Out:
# Adaptive Query Execution Enabled: true

# %%
# Define paths
base_input = "../data/"
bronze_output = "../delta/bronze/"

# %%
# Bronze ingestion for all Olist tables
datasets = {
    "customers": "olist_customers_dataset.csv",
    "orders": "olist_orders_dataset.csv",
    "order_items": "olist_order_items_dataset.csv",
    "order_payments": "olist_order_payments_dataset.csv",
    "order_reviews": "olist_order_reviews_dataset.csv",
    "products": "olist_products_dataset.csv",
    "sellers": "olist_sellers_dataset.csv",
    "geolocation": "olist_geolocation_dataset.csv",
    "category_translation": "product_category_name_translation.csv"
}

# %%
for name, filename in datasets.items():
    input_path = f"{base_input}{filename}"
    output_path = f"{bronze_output}{name}"

    print(f"\n[INFO] Ingesting {name} → {output_path}")
    
    if name == "orders":  # partition only orders
        ingest_csv(spark, input_path, output_path, partition_col="order_purchase_month", target_file_rows=50000)
    else:
        ingest_csv(spark, input_path, output_path, target_file_rows=50000)

    # Read back from Delta & show
    df = spark.read.format("delta").load(output_path)
    print(f"[INFO] Showing {name} table (first 5 rows):")
    df.show(5, truncate=False)
# Out:
# [INFO] Ingesting customers → ../delta/bronze/customers
# [INFO] Ingested ../data/olist_customers_dataset.csv → ../delta/bronze/customers
# [INFO] Files written under ../delta/bronze/customers:
#    part-00000-02c6ad1c-aea8-4d34-a24e-827acddad19b-c000.snappy.parquet → 3.36 MB
#    part-00001-b2b5979f-2a0d-4642-b280-79bee37d5a3e-c000.snappy.parquet → 3.35 MB
# [INFO] Showing customers table (first 5 rows):
# +--------------------------------+--------------------------------+------------------------+-------------+--------------+
# |customer_id                     |customer_unique_id              |customer_zip_code_prefix|customer_city|customer_state|
# +--------------------------------+--------------------------------+------------------------+-------------+--------------+
# |15357da0aa538a1e5efabe63f0d71095|57f66dc16e5edbe9417e1e21c783b5a9|13010                   |campinas     |SP            |
# |47aa66905ec3df607310af4988d34bca|58aaf012cc88d1de4b976f45e059ddf5|4844                    |sao paulo    |SP            |
# |9015549e1e0438244f52123c59498fa6|e22c7e55a547f8d9bc30d2957ba1c9c5|45810                   |porto seguro |BA            |
# |9a12e00f66d6b5794f5825e62dc55a72|af9a735e918bd45a036e1a1a4cb67416|5821                    |sao paulo    |SP            |
# |16f5cb910633b2a0a8d93b9da0168381|e57af309c40f1e310fbf11e8374b0c32|9361                    |maua         |SP            |
# +--------------------------------+--------------------------------+------------------------+-------------+--------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting orders → ../delta/bronze/orders
# [INFO] Added derived partition column 'order_purchase_month'
# [INFO] Ingested ../data/olist_orders_dataset.csv → ../delta/bronze/orders
# [INFO] Files written under ../delta/bronze/orders:
#    part-00000-2b99bc8c-79e7-490d-a6ec-dcc2bab749f5.c000.snappy.parquet → 0.00 MB
#    part-00001-45caa01a-89fe-4a4a-9fad-f0b06a6ee504.c000.snappy.parquet → 0.00 MB
# +--------------------------------+--------------------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+--------------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting order_items → ../delta/bronze/order_items
# [INFO] Ingested ../data/olist_order_items_dataset.csv → ../delta/bronze/order_items
# [INFO] Files written under ../delta/bronze/order_items:
#    part-00000-1a2bdd57-81d3-4a38-977c-450158ef6b6a-c000.snappy.parquet → 3.10 MB
#    part-00000-2ad1c093-f14e-4fde-97f7-be4848bdd8f3-c001.snappy.parquet → 0.49 MB
#    part-00001-297ccc77-1d7e-433d-89c3-ebf7be34e732-c001.snappy.parquet → 0.49 MB
#    part-00001-3bb0077c-cb66-405e-b132-50aa513862f0-c000.snappy.parquet → 3.09 MB
# [INFO] Showing order_items table (first 5 rows):
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+------+-------------+
# |order_id                        |order_item_id|product_id                      |seller_id                       |shipping_limit_date|price |freight_value|
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+------+-------------+
# |02b0bf9164ac7753f9880e46dba17f6c|2            |f9d151cf2fc10d41cce64b782856320f|e9d99831abad74458942f21e16f33f92|2017-06-22 17:15:21|19.74 |2.91         |
# |34be9444467af1f6d854ea4054a47e85|1            |6c321ed0f47858a8650f4104771224b5|6560211a19b47992c3666cc44a7e94c0|2017-11-27 20:26:44|49.0  |14.1         |
# |0c29afa3d55c9d983ff14ae80e79984a|1            |6abd84909e8ed79ef808c16f90b91093|da8622b14eb17ae2831f4ac5b9dab84a|2018-01-15 18:49:43|29.9  |8.11         |
# |362cc20bf09835f4398cedd319fb7d8e|1            |a5bc1334f1762ce0a844f3f694dc08e1|1900267e848ceeba8fa32d80c1a5f5a8|2018-04-04 03:28:46|69.99 |27.22        |
# |34a1e7e0bd6987d552a7b050ad68a314|1            |3f2146831fb32311f584fd931a0d51ad|725c32fa80c2faacc4fc88450d27314e|2017-05-22 03:15:34|159.99|9.93         |
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+------+-------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting order_payments → ../delta/bronze/order_payments
# [INFO] Ingested ../data/olist_order_payments_dataset.csv → ../delta/bronze/order_payments
# [INFO] Files written under ../delta/bronze/order_payments:
#    part-00000-09264fab-f7ee-4566-a54b-fab082e9f65c-c001.snappy.parquet → 0.07 MB
#    part-00000-aae2db3c-56f7-4d14-8363-ff024e128364-c000.snappy.parquet → 1.79 MB
#    part-00001-9037f30e-bbe2-465f-bf9a-cab3c8d0fdd2-c000.snappy.parquet → 1.79 MB
#    part-00001-a7cf20a0-b0d5-4bc3-afd1-bab252fc817e-c001.snappy.parquet → 0.07 MB
# [INFO] Showing order_payments table (first 5 rows):
# +--------------------------------+------------------+------------+--------------------+-------------+
# |order_id                        |payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------------------+------------------+------------+--------------------+-------------+
# |1fa8e437e5fc2d62dee8989fd5e8df97|1                 |credit_card |10                  |105.39       |
# |2a77e75a84066bc18c31a02f6b98dfca|1                 |credit_card |1                   |95.22        |
# |a4aecfaa64d23ee3758985066edde9c4|1                 |credit_card |3                   |95.4         |
# |a12de642288c88d6a5aec20f46a12fa6|1                 |credit_card |1                   |57.11        |
# |593f849c29daaeee17ee32baa44795d6|1                 |credit_card |10                  |1218.34      |
# +--------------------------------+------------------+------------+--------------------+-------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting order_reviews → ../delta/bronze/order_reviews
# [INFO] Ingested ../data/olist_order_reviews_dataset.csv → ../delta/bronze/order_reviews
# [INFO] Files written under ../delta/bronze/order_reviews:
#    part-00000-62f5c210-8d2c-4954-baca-189ad589a7b8-c000.snappy.parquet → 4.44 MB
#    part-00000-ad490050-f9a9-4755-85e7-601bb0ac8015-c001.snappy.parquet → 0.19 MB
#    part-00001-00be5362-adbe-4b48-a700-71aa105ff50c-c000.snappy.parquet → 4.44 MB
#    part-00001-493332cf-7ccd-4304-bbdb-bb1be7efe8e2-c001.snappy.parquet → 0.19 MB
# [INFO] Showing order_reviews table (first 5 rows):
# +--------------------------------+--------------------------------+------------+--------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# |review_id                       |order_id                        |review_score|review_comment_title|review_comment_message                                                                                                                                                  |review_creation_date|review_answer_timestamp|
# +--------------------------------+--------------------------------+------------+--------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# |f570a7c432f0f9a8c81b515a8f903cb9|1762aa0ce22469c003348a42e46f5269|1           |NULL                |Não recebi o produto comprado, e nenhuma informação do mesmo, estou totalmente insatisfeita com essa loja.                                                              |2017-09-17 00:00:00 |2017-09-18 18:48:35    |
# |11ef0a68b4f16f04e4ca18c6977b719e|f72322b96b8a40b181a18018f99d72a4|1           |NULL                |Moito imatura essa loja, não cumpre com seus clientes o que promete, atraso e ainda cobra um frete muito caro, para não ser entregue, estou aguardando o produto chegar.|2017-09-10 00:00:00 |2017-09-12 09:59:31    |
# |a1fe6a9c52d62387ae4bb20987c0ef67|3457d1d203987e3898c4516a101b5d36|2           |NULL                |NULL                                                                                                                                                                    |2017-08-18 00:00:00 |2017-08-21 18:00:55    |
# |3effc12f415364dab63960a95fdd77af|683f04dde2c04fd7b5a1a520a4abe379|5           |NULL                |Muito bom                                                                                                                                                               |2018-03-30 00:00:00 |2018-03-31 01:00:41    |
# |0b4e93a104a76325206f7a3ea0ff5e2e|dc2f00579e6ddf8d0b112e29635b0d1a|5           |NULL                |Chegou antes do prazo muito bom, adorei                                                                                                                                 |2018-03-16 00:00:00 |2018-03-16 13:03:17    |
# +--------------------------------+--------------------------------+------------+--------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting products → ../delta/bronze/products
# [INFO] Ingested ../data/olist_products_dataset.csv → ../delta/bronze/products
# [INFO] Files written under ../delta/bronze/products:
#    part-00000-6a286d25-79fb-4d9d-9d2f-7d9d3473defe-c000.snappy.parquet → 0.66 MB
#    part-00001-110d7973-33c2-46ec-b83f-4436219c6add-c000.snappy.parquet → 0.66 MB
# [INFO] Showing products table (first 5 rows):
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |product_id                      |product_category_name    |product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |aa5a3fa92cb1221a38267376d25cfd8a|cama_mesa_banho          |52                 |276                       |1                 |1150            |41               |13               |13              |
# |c7bd850b9a356ee44d5a2a55f7a5b657|esporte_lazer            |63                 |1562                      |10                |1150            |20               |16               |20              |
# |1953c4e517bc25739bc4223ede2ff5bc|relogios_presentes       |53                 |2390                      |1                 |800             |25               |14               |16              |
# |24fee4a800146a47846fa0e345b6d6ed|agro_industria_e_comercio|22                 |353                       |1                 |800             |20               |20               |20              |
# |269616df4c79febdae020f2d978594ed|climatizacao             |60                 |595                       |4                 |2400            |16               |40               |15              |
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting sellers → ../delta/bronze/sellers
# [INFO] Ingested ../data/olist_sellers_dataset.csv → ../delta/bronze/sellers
# [INFO] Files written under ../delta/bronze/sellers:
#    part-00000-78fec5a0-b4b1-4e92-a223-2d63d08ccbe0-c000.snappy.parquet → 0.06 MB
#    part-00001-25a62fed-9111-49c7-9394-7d4f2d57a00e-c000.snappy.parquet → 0.06 MB
# [INFO] Showing sellers table (first 5 rows):
# +--------------------------------+----------------------+--------------+------------+
# |seller_id                       |seller_zip_code_prefix|seller_city   |seller_state|
# +--------------------------------+----------------------+--------------+------------+
# |918f6fbcf3ab724d805867303e593a1b|13273                 |valinhos      |SP          |
# |1588ac4010787100dddef64568f0ae35|87045                 |maringa       |PR          |
# |06579cb253ecd5a3a12a9e6eb6bf8f47|4007                  |sao paulo - sp|SP          |
# |07bf9669d84d1f11be443a9dd938f698|4761                  |sao paulo     |SP          |
# |f1c1ac3f3efc07e659c035008e615e66|2119                  |sao paulo     |SP          |
# +--------------------------------+----------------------+--------------+------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting geolocation → ../delta/bronze/geolocation
# [INFO] Ingested ../data/olist_geolocation_dataset.csv → ../delta/bronze/geolocation
# [INFO] Files written under ../delta/bronze/geolocation:
#    part-00000-36641149-89b4-4958-ae05-f74acca20a1c-c001.snappy.parquet → 0.00 MB
#    part-00000-bad67270-c589-49ec-a7ec-0f45a5080180-c000.snappy.parquet → 1.01 MB
#    part-00001-b77ccb6c-a562-42c5-bf1f-df3bceb14d1b-c000.snappy.parquet → 1.01 MB
#    part-00001-dc439381-cd8f-47de-b0d5-5d2c1de2b36a-c001.snappy.parquet → 0.00 MB
#    part-00002-46d8f5b5-68c1-4f01-ae40-1d3f4f01a029-c001.snappy.parquet → 0.00 MB
#    part-00002-68363f47-f81c-49b1-bbbc-6ae499fdfa8d-c000.snappy.parquet → 1.02 MB
#    part-00003-19bc069b-d438-4b12-934d-0304e8145e3a-c000.snappy.parquet → 1.01 MB
#    part-00003-9d04a231-71d1-4a96-8094-8f58605c4253-c001.snappy.parquet → 0.00 MB
#    part-00004-b553df20-6d70-4940-a914-fb0e3ae99b41-c001.snappy.parquet → 0.00 MB
#    part-00004-d4f24c3b-b53d-461b-8beb-2cd196f41f36-c000.snappy.parquet → 1.01 MB
#    part-00005-41197494-6b0f-4bde-adfc-d27c7ea1b5f9-c001.snappy.parquet → 0.00 MB
#    part-00005-bd6274f5-2e27-401b-9725-83885b3bbc18-c000.snappy.parquet → 1.02 MB
#    part-00006-099c5792-6da3-4b49-b1e1-9a2697aa5c1f-c001.snappy.parquet → 0.00 MB
#    part-00006-dbc9dabf-1dd0-465b-b534-792f5d339beb-c000.snappy.parquet → 1.02 MB
#    part-00007-c920688f-efb7-49f8-a306-7349eb354ee4-c000.snappy.parquet → 1.02 MB
------+-----------------+
# |geolocation_zip_code_prefix|geolocation_lat    |geolocation_lng   |geolocation_city    |geolocation_state|
# +---------------------------+-------------------+------------------+--------------------+-----------------+
# |1208                       |-23.53601276741302 |-46.63979908367479|sao paulo           |SP               |
# |9361                       |-23.690332014778814|-46.46202243767077|maua                |SP               |
# |5541                       |-23.587462029608687|-46.74321900887182|são paulo           |SP               |
# |6850                       |-23.715831127491686|-46.85103183305166|itapecerica da serra|SP               |
# |3382                       |-23.578639250072108|-46.52940445475793|sao paulo           |SP               |
# +---------------------------+-------------------+------------------+--------------------+-----------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting category_translation → ../delta/bronze/category_translation
# [INFO] Ingested ../data/product_category_name_translation.csv → ../delta/bronze/category_translation
# [INFO] Files written under ../delta/bronze/category_translation:
#    part-00000-4f0647f0-b216-4100-b892-6e2ad2016efc-c000.snappy.parquet → 0.00 MB
#    part-00001-10317b5e-e662-4b2d-8309-343617c2d27c-c000.snappy.parquet → 0.00 MB
# [INFO] Showing category_translation table (first 5 rows):
# +-----------------------+-----------------------------+
# |product_category_name  |product_category_name_english|
# +-----------------------+-----------------------------+
# |esporte_lazer          |sports_leisure               |
# |seguros_e_servicos     |security_and_services        |
# |livros_interesse_geral |books_general_interest       |
# |sinalizacao_e_seguranca|signaling_and_security       |
# |ferramentas_jardim     |garden_tools                 |
# +-----------------------+-----------------------------+
# only showing top 5 rows

# %%
silver_output = "../delta/silver/"

# %%
# Curate Silver Layer
curate_sales(spark, bronze_base=bronze_output, silver_base=silver_output)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Curate Silver Layer
# ----> 2 curate_sales(spark, bronze_base="../delta/bronze", silver_base="../delta/silver")
#
# File ~\Desktop\spark-olist-pipeline\src\silver.py:32, in curate_sales(spark, bronze_base, silver_base)
#      24 def cleanse_text_fields(df: DataFrame, columns: list) -> DataFrame:
#      25     for c in columns:
#      26         df = df.withColumn(
#      27             c,
#      28             trim(
#      29                 lower(
#      30                     regexp_replace(col(c), r"[^a-zA-ZÀ-ÿ0-9\s]", "")  # remove special chars
#      31                 )
# ---> 32             )
#      33         )
#      34         # collapse multiple spaces into one
#      35         df = df.withColumn(c, regexp_replace(col(c), r"\s+", " "))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\sql\readwriter.py:307, in DataFrameReader.load(self, path, format, schema, **options)
#     305 self.options(**options)
#     306 if isinstance(path, str):
# --> 307     return self._df(self._jreader.load(path))
#     308 elif path is not None:
#     309     if type(path) != list:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyspark\errors\exceptions\captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     177 def deco(*a: Any, **kw: Any) -> Any:
#     178     try:
# --> 179         return f(*a, **kw)
#     180     except Py4JJavaError as e:
#     181         converted = convert_exception(e.java_exception)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\py4j\protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     324 value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#     330     raise Py4JError(
#     331         "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332         format(target_id, ".", name, value))
#
# Py4JJavaError: An error occurred while calling o277.load.
# : java.lang.IllegalStateException: No active or default Spark session found
# 	at org.apache.spark.sql.SparkSession$.$anonfun$active$2(SparkSession.scala:1202)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at org.apache.spark.sql.SparkSession$.$anonfun$active$1(SparkSession.scala:1202)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at org.apache.spark.sql.SparkSession$.active(SparkSession.scala:1201)
# 	at org.apache.spark.sql.delta.sources.DeltaDataSource.getTable(DeltaDataSource.scala:69)
# 	at org.apache.spark.sql.execution.datasources.v2.DataSourceV2Utils$.getTableFromProvider(DataSourceV2Utils.scala:92)
# 	at org.apache.spark.sql.execution.datasources.v2.DataSourceV2Utils$.loadV2Source(DataSourceV2Utils.scala:140)
# 	at org.apache.spark.sql.DataFrameReader.$anonfun$load$1(DataFrameReader.scala:210)
# 	at scala.Option.flatMap(Option.scala:271)
# 	at org.apache.spark.sql.DataFrameReader.load(DataFrameReader.scala:208)
# 	at org.apache.spark.sql.DataFrameReader.load(DataFrameReader.scala:186)
# 	at sun.reflect.GeneratedMethodAccessor164.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
# Verify Silver
print("\n[INFO] Silver Layer Sales Table:")
sales_df = spark.read.format("delta").load(f"{silver_output}/sales")
sales_df.show(5, truncate=False)

# %%
spark.stop()
print("Bronze layer ingestion completed successfully!")
