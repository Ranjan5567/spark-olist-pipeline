# %%
import os
os.environ["PYSPARK_PYTHON"] = r"C:\Users\ranjan\Desktop\spark-olist-pipeline\venv\Scripts\python.exe"
os.environ["PYSPARK_DRIVER_PYTHON"] = r"C:\Users\ranjan\Desktop\spark-olist-pipeline\venv\Scripts\python.exe"
os.environ["spark.python.worker.reuse"] = "true"

# %%
import sys
sys.path.append(os.path.abspath("../src")) 
from bronze import create_spark_session, ingest_csv
from silver import curate_sales
spark = create_spark_session("OlistPipeline")

# %%
# Check AQE
print("Adaptive Query Execution Enabled:", spark.conf.get("spark.sql.adaptive.enabled"))
# Out:
# Adaptive Query Execution Enabled: true

# %%
# Define paths
base_input = "../data/"
bronze_output = "../delta/bronze/"

# %%
# Bronze ingestion for all Olist tables
datasets = {
    "customers": "olist_customers_dataset.csv",
    "orders": "olist_orders_dataset.csv",
    "order_items": "olist_order_items_dataset.csv",
    "order_payments": "olist_order_payments_dataset.csv",
    "order_reviews": "olist_order_reviews_dataset.csv",
    "products": "olist_products_dataset.csv",
    "sellers": "olist_sellers_dataset.csv",
    "geolocation": "olist_geolocation_dataset.csv",
    "category_translation": "product_category_name_translation.csv"
}

# %%
for name, filename in datasets.items():
    input_path = f"{base_input}{filename}"
    output_path = f"{base_output}{name}"

    print(f"\n[INFO] Ingesting {name} → {output_path}")
    
    if name == "orders":  # partition only orders
        ingest_csv(spark, input_path, output_path, partition_col="order_purchase_month", target_file_rows=50000)
    else:
        ingest_csv(spark, input_path, output_path, target_file_rows=50000)

    # Read back from Delta & show
    df = spark.read.format("delta").load(output_path)
    print(f"[INFO] Showing {name} table (first 5 rows):")
    df.show(5, truncate=False)
# Out:
# [INFO] Ingesting customers → ../delta/bronze/customers
# [INFO] Ingested ../data/olist_customers_dataset.csv → ../delta/bronze/customers
# [INFO] Files written under ../delta/bronze/customers:
#    part-00000-485a72ab-6d08-4706-877a-2640e9a05953-c000.snappy.parquet → 3.36 MB
#    part-00001-8ce4f704-cd41-4916-a119-2379bfec8ecd-c000.snappy.parquet → 3.35 MB
# [INFO] Showing customers table (first 5 rows):
# +--------------------------------+--------------------------------+------------------------+--------------------+--------------+
# |customer_id                     |customer_unique_id              |customer_zip_code_prefix|customer_city       |customer_state|
# +--------------------------------+--------------------------------+------------------------+--------------------+--------------+
# |6ae91e04653dc3a0c205363ffff0081f|1dde89b524bd2ce5480df99d22539136|28911                   |cabo frio           |RJ            |
# |ff84d0fa669f79bdc394cadf5d651cf2|4fd1b2e7c09c60c05762f31151d464f8|13236                   |campo limpo paulista|SP            |
# |25936c2bf3471a32f522df4e5949e725|e49c82ca5e5ebe3153400c1adc06cc9a|99700                   |erechim             |RS            |
# |ec969a27db96260fb93c52ab2c073b5c|e75ef15643b054b600909c9eeb5a8fde|55292                   |garanhuns           |PE            |
# |3426e7a4ab70dfdf2fe8ae2060984be3|a784c03aa8b195a1b7bf3894516de858|30690                   |belo horizonte      |MG            |
# +--------------------------------+--------------------------------+------------------------+--------------------+--------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting orders → ../delta/bronze/orders
# [INFO] Added derived partition column 'order_purchase_month'
# [INFO] Ingested ../data/olist_orders_dataset.csv → ../delta/bronze/orders
# [INFO] Files written under ../delta/bronze/orders:
#    part-00000-fd6a2d71-a9a1-48da-9d4d-5cf08c5e13ae.c000.snappy.parquet → 0.00 MB
#    part-00001-76f43ebc-0fa3-4fc4-8b70-b8feedaf2646.c000.snappy.parquet → 0.00 MB
#    part-00000-511fcb29-14cf-459b-8c8b-7e391cdd4dbd.c000.snappy.parquet → 0.02 MB
#    part-00001-88d4f0f6-4d4e-43a6-aa09-1f48c08272e3.c000.snappy.parquet → 0.02 MB
#    part-00000-6ceb7419-375e-498d-89a3-86b93ce8a187.c000.snappy.parquet → 0.00 MB
#    part-00000-16216640-5b28-4a1e-8eed-89ff2fb4c403.c000.snappy.parquet → 0.04 MB
#    part-00001-9150d345-d810-46c8-b23d-4b2b8c24ef7f.c000.snappy.parquet → 0.04 MB
#    part-00000-711f7e2f-de5e-4864-a315-9446353a5c69.c000.snappy.parquet → 0.09 MB
#    part-00001-6f009b07-b4ae-484a-8a8e-349e260c0e44.c000.snappy.parquet → 0.09 MB
#    part-00000-c9faa701-a816-40e5-a4ee-63eac3abd83d.c000.snappy.parquet → 0.14 MB
#    part-00001-fba2151d-c7bf-4755-a545-df9c939c9736.c000.snappy.parquet → 0.13 MB
#    part-00000-998a19c2-1594-41d9-ae38-1377c20c5012.c000.snappy.parquet → 0.12 MB
#    part-00001-58d9fa90-4f30-4aa7-bdda-9cbe3a19fc65.c000.snappy.parquet → 0.12 MB
#    part-00000-f9e4819e-8c34-4a69-a8ee-66fe5980c384.c000.snappy.parquet → 0.18 MB
#    part-00001-275218ec-ef35-4b27-b628-a86229a1541b.c000.snappy.parquet → 0.18 MB
#    part-00000-d7a94a8d-1b12-4d4d-8c84-0df4817a4354.c000.snappy.parquet → 0.16 MB
#    part-00001-21cb4c73-39e0-4012-9833-a1688d381c8f.c000.snappy.parquet → 0.16 MB
#    part-00000-a9b78393-e32d-450a-bd81-0c37aa13c373.c000.snappy.parquet → 0.19 MB
#    part-00001-73e470aa-ef26-418c-b5b4-cec778104bf6.c000.snappy.parquet → 0.21 MB
#    part-00000-87e3cc47-2195-4774-8388-ec34072d9fd8.c000.snappy.parquet → 0.22 MB
#    part-00001-3a85f29c-cb1c-4500-bad8-e5186d9c16a7.c000.snappy.parquet → 0.21 MB
#    part-00000-7eff31a5-08e5-4a2a-bd4c-0cc66c7d7aa5.c000.snappy.parquet → 0.21 MB
#    part-00001-f7eed63d-23e9-474d-83f2-47e778992212.c000.snappy.parquet → 0.21 MB
#    part-00000-a9d4e184-49bb-4ac2-82db-68c9a17b6641.c000.snappy.parquet → 0.23 MB
#    part-00001-e5ce8ed6-e1de-48a6-b132-6e56737ea041.c000.snappy.parquet → 0.24 MB
#    part-00000-22a078b9-846f-4aea-89d8-8c7b92e688c7.c000.snappy.parquet → 0.37 MB
#    part-00001-323ab8e3-7bf6-4f43-a75e-d840ae743fb4.c000.snappy.parquet → 0.38 MB
#    part-00000-c7954837-4e03-40dd-ba10-74aec26f2472.c000.snappy.parquet → 0.29 MB
#    part-00001-dc1658ea-c789-4ff5-84f2-cc86b8bab5d2.c000.snappy.parquet → 0.27 MB
#    part-00000-07b4445d-bc8d-4d39-a880-16e14c057afb.c000.snappy.parquet → 0.37 MB
#    part-00001-3a7f70e3-7748-4434-89ae-20b6ffe3c28e.c000.snappy.parquet → 0.35 MB
#    part-00000-14435225-5c41-4f79-8687-b45425fb03a9.c000.snappy.parquet → 0.34 MB
#    part-00001-d238cf17-7e44-4d23-92cb-6d91bcbc8a87.c000.snappy.parquet → 0.33 MB
#    part-00000-4bc5f716-841d-4f9e-b00c-8969c8d03b08.c000.snappy.parquet → 0.36 MB
#    part-00001-6770c4a7-afb4-411e-af16-6096674cf45c.c000.snappy.parquet → 0.36 MB
#    part-00000-b3fdc3a3-7674-4e00-ab72-d9cab0eb20cd.c000.snappy.parquet → 0.34 MB
#    part-00001-27b3ddff-a1f7-41cc-8702-192e6cad8fa3.c000.snappy.parquet → 0.34 MB
#    part-00000-d306c6ab-acc1-4bc7-8f56-a0691dfdd266.c000.snappy.parquet → 0.32 MB
#    part-00001-29732269-4afd-4cd1-affd-14ede09fe8d0.c000.snappy.parquet → 0.33 MB
#    part-00000-3e752b07-e655-49c8-8573-d1be14182f3f.c000.snappy.parquet → 0.30 MB
#    part-00001-2109b195-80fe-410d-be6a-868c21f47eff.c000.snappy.parquet → 0.30 MB
#    part-00000-4a55f4b9-e02d-47e8-9d32-011eed0cf829.c000.snappy.parquet → 0.30 MB
#    part-00001-a293675d-f5cf-4372-8554-cb658d9e0dae.c000.snappy.parquet → 0.30 MB
#    part-00000-cfd310db-f0dd-4939-931f-c6c64b44348b.c000.snappy.parquet → 0.31 MB
#    part-00001-a455349f-52de-4729-821e-601f3935b3d6.c000.snappy.parquet → 0.31 MB
#    part-00000-090c284b-ec06-42c3-a12d-8747e5e84618.c000.snappy.parquet → 0.00 MB
#    part-00001-a0d4d5f2-7b58-4520-895d-4a1f1a649dc8.c000.snappy.parquet → 0.00 MB
#    part-00000-947702eb-bff1-4c9d-a8d1-c04e1e86344c.c000.snappy.parquet → 0.00 MB
#    part-00001-0e4ef96d-9731-4808-9937-488c4a7fedeb.c000.snappy.parquet → 0.00 MB
# [INFO] Showing orders table (first 5 rows):
# +--------------------------------+--------------------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+--------------------+
# |order_id                        |customer_id                     |order_status|order_purchase_timestamp|order_approved_at  |order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|order_purchase_month|
# +--------------------------------+--------------------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+--------------------+
# |dc5f6cd4492bbffe5bcda9b87856c9a5|2ebf822bbf33241c7bffb42235519f92|delivered   |2016-10-05 13:12:43     |2016-10-06 15:47:29|2016-10-21 16:34:58         |2016-10-27 12:33:29          |2016-11-29 00:00:00          |2016-10             |
# |7ac6f4778cd283c6b76c66fe1e0d4431|ed8be358abd6a8b37ba8cc9d485e7bbb|delivered   |2016-10-07 10:11:42     |2016-10-07 11:22:48|2016-10-15 12:38:53         |2016-10-18 17:21:51          |2016-12-05 00:00:00          |2016-10             |
# |e2144124f98f3bf46939bc5183104041|bd0342f59a3b8ddc416bd048b2b5d0fb|delivered   |2016-10-06 20:06:26     |2016-10-08 11:00:24|2016-10-12 11:00:25         |2016-10-15 11:00:25          |2016-11-28 00:00:00          |2016-10             |
# |063b573b88fc80e516aba87df524f809|285195a5b585842e25bd1ef9015a8413|shipped     |2016-10-07 19:17:00     |2016-10-07 19:29:20|2016-10-30 10:23:36         |NULL                         |2016-12-01 00:00:00          |2016-10             |
# |a8846701b9f3e21e64c9062ed3f4dfd7|814d58f5b1b9829ab9a1d690b13dba62|delivered   |2016-10-07 11:33:35     |2016-10-07 12:15:23|2016-10-11 12:15:24         |2016-10-14 12:15:24          |2016-12-05 00:00:00          |2016-10             |
# +--------------------------------+--------------------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+--------------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting order_items → ../delta/bronze/order_items
# [INFO] Ingested ../data/olist_order_items_dataset.csv → ../delta/bronze/order_items
# [INFO] Files written under ../delta/bronze/order_items:
#    part-00000-688fd5cb-7f49-4639-be59-ec183ebbaf90-c000.snappy.parquet → 3.10 MB
#    part-00000-91509ce9-ff3b-4da1-9cf8-21d562288d33-c001.snappy.parquet → 0.49 MB
#    part-00001-8b35a216-b527-4e3a-ab67-9699ddbbddd5-c001.snappy.parquet → 0.49 MB
#    part-00001-b98be6a9-c37b-48e2-b47b-6c23d688a94a-c000.snappy.parquet → 3.09 MB
# [INFO] Showing order_items table (first 5 rows):
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+-----+-------------+
# |order_id                        |order_item_id|product_id                      |seller_id                       |shipping_limit_date|price|freight_value|
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+-----+-------------+
# |b606a684f47f6156083911fb09287f91|1            |875e0d1c97176d76e9b04c98d06383d2|e8b4225284fbb02d16f200513f1f395d|2018-04-18 21:52:46|145.9|15.11        |
# |ec0eba3b4fbad8fda2b94df042100196|1            |be642ced82a99a398aa76d720cf47d19|7b07b3c7487f0ea825fc6df75abd658b|2017-11-30 13:31:02|57.8 |21.6         |
# |b6918562ae8b764ad6d0022da12051fb|2            |9d838a7fbaba7fca5f1fad259984063a|897060da8b9a21f655304d50fd935913|2018-03-26 16:29:31|59.0 |18.29        |
# |f1b19188d070474e6b24f5e12da6ef4c|1            |b76364870c38ddd7dcc9dd9ab5abeeb4|2a6fbeaa7ab9e5d59a35841a8da71ce4|2017-12-07 13:58:50|48.9 |17.6         |
# |aa8315492e537030e29f1bc252d26cb1|1            |7e0dc102074f8285580c9777f79c90cf|e26901d5ab434ce92fd9b5c256820a4e|2017-02-23 12:37:14|39.9 |10.96        |
# +--------------------------------+-------------+--------------------------------+--------------------------------+-------------------+-----+-------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting order_payments → ../delta/bronze/order_payments
# [INFO] Ingested ../data/olist_order_payments_dataset.csv → ../delta/bronze/order_payments
# [INFO] Files written under ../delta/bronze/order_payments:
#    part-00000-de5868e5-c3bb-4422-b073-35336a257e67-c001.snappy.parquet → 0.07 MB
#    part-00000-f88b8ca7-fa91-4ac7-9226-86255305c2f9-c000.snappy.parquet → 1.79 MB
#    part-00001-1982a4f4-299d-4c04-a230-6eed866e9ffe-c001.snappy.parquet → 0.07 MB
#    part-00001-4efb8445-556d-40dc-8821-304b2ae2ff13-c000.snappy.parquet → 1.79 MB
# [INFO] Showing order_payments table (first 5 rows):
# +--------------------------------+------------------+------------+--------------------+-------------+
# |order_id                        |payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------------------+------------------+------------+--------------------+-------------+
# |e313e28018f250ccec7488220bbfd285|1                 |credit_card |1                   |44.38        |
# |9c03496a411754169e1433dc70a583f0|2                 |voucher     |1                   |123.82       |
# |86fe069057d591923b2a30a47b2fa5ab|1                 |credit_card |3                   |47.0         |
# |558fa371b24282233214767214895e95|1                 |credit_card |1                   |122.27       |
# |60566939937556f587e9c32e761f794b|1                 |credit_card |8                   |348.07       |
# +--------------------------------+------------------+------------+--------------------+-------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting order_reviews → ../delta/bronze/order_reviews
# [INFO] Ingested ../data/olist_order_reviews_dataset.csv → ../delta/bronze/order_reviews
# [INFO] Files written under ../delta/bronze/order_reviews:
#    part-00000-74577df8-a225-4a39-854e-b0f064247a3e-c000.snappy.parquet → 4.44 MB
#    part-00000-e1a2095a-7f14-4c98-8d90-0d6e8d6178f4-c001.snappy.parquet → 0.19 MB
#    part-00001-069aa204-9b99-4c45-9842-846547f00eb8-c001.snappy.parquet → 0.19 MB
#    part-00001-be0ea08c-016d-4088-9e0f-ea3ba79f4a20-c000.snappy.parquet → 4.44 MB
# [INFO] Showing order_reviews table (first 5 rows):
# +--------------------------------+--------------------------------+------------+--------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# |review_id                       |order_id                        |review_score|review_comment_title|review_comment_message                                                                                                                                                  |review_creation_date|review_answer_timestamp|
# +--------------------------------+--------------------------------+------------+--------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# |f570a7c432f0f9a8c81b515a8f903cb9|1762aa0ce22469c003348a42e46f5269|1           |NULL                |Não recebi o produto comprado, e nenhuma informação do mesmo, estou totalmente insatisfeita com essa loja.                                                              |2017-09-17 00:00:00 |2017-09-18 18:48:35    |
# |11ef0a68b4f16f04e4ca18c6977b719e|f72322b96b8a40b181a18018f99d72a4|1           |NULL                |Moito imatura essa loja, não cumpre com seus clientes o que promete, atraso e ainda cobra um frete muito caro, para não ser entregue, estou aguardando o produto chegar.|2017-09-10 00:00:00 |2017-09-12 09:59:31    |
# |a1fe6a9c52d62387ae4bb20987c0ef67|3457d1d203987e3898c4516a101b5d36|2           |NULL                |NULL                                                                                                                                                                    |2017-08-18 00:00:00 |2017-08-21 18:00:55    |
# |3effc12f415364dab63960a95fdd77af|683f04dde2c04fd7b5a1a520a4abe379|5           |NULL                |Muito bom                                                                                                                                                               |2018-03-30 00:00:00 |2018-03-31 01:00:41    |
# |0b4e93a104a76325206f7a3ea0ff5e2e|dc2f00579e6ddf8d0b112e29635b0d1a|5           |NULL                |Chegou antes do prazo muito bom, adorei                                                                                                                                 |2018-03-16 00:00:00 |2018-03-16 13:03:17    |
# +--------------------------------+--------------------------------+------------+--------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+-----------------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting products → ../delta/bronze/products
# [INFO] Ingested ../data/olist_products_dataset.csv → ../delta/bronze/products
# [INFO] Files written under ../delta/bronze/products:
#    part-00000-6331f47e-2d43-475e-93b5-2b174a473a82-c000.snappy.parquet → 0.66 MB
#    part-00001-07196bba-fdcd-4447-b44c-1cbdac8d59bb-c000.snappy.parquet → 0.66 MB
# [INFO] Showing products table (first 5 rows):
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |product_id                      |product_category_name    |product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |aa5a3fa92cb1221a38267376d25cfd8a|cama_mesa_banho          |52                 |276                       |1                 |1150            |41               |13               |13              |
# |c7bd850b9a356ee44d5a2a55f7a5b657|esporte_lazer            |63                 |1562                      |10                |1150            |20               |16               |20              |
# |1953c4e517bc25739bc4223ede2ff5bc|relogios_presentes       |53                 |2390                      |1                 |800             |25               |14               |16              |
# |24fee4a800146a47846fa0e345b6d6ed|agro_industria_e_comercio|22                 |353                       |1                 |800             |20               |20               |20              |
# |269616df4c79febdae020f2d978594ed|climatizacao             |60                 |595                       |4                 |2400            |16               |40               |15              |
# +--------------------------------+-------------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting sellers → ../delta/bronze/sellers
# [INFO] Ingested ../data/olist_sellers_dataset.csv → ../delta/bronze/sellers
# [INFO] Files written under ../delta/bronze/sellers:
#    part-00000-45970244-423c-460a-b9b7-1674897b215b-c000.snappy.parquet → 0.06 MB
#    part-00001-9c5d5a2e-4833-4e4d-a362-26bfa55aeb7a-c000.snappy.parquet → 0.06 MB
# [INFO] Showing sellers table (first 5 rows):
# +--------------------------------+----------------------+--------------+------------+
# |seller_id                       |seller_zip_code_prefix|seller_city   |seller_state|
# +--------------------------------+----------------------+--------------+------------+
# |918f6fbcf3ab724d805867303e593a1b|13273                 |valinhos      |SP          |
# |1588ac4010787100dddef64568f0ae35|87045                 |maringa       |PR          |
# |06579cb253ecd5a3a12a9e6eb6bf8f47|4007                  |sao paulo - sp|SP          |
# |07bf9669d84d1f11be443a9dd938f698|4761                  |sao paulo     |SP          |
# |f1c1ac3f3efc07e659c035008e615e66|2119                  |sao paulo     |SP          |
# +--------------------------------+----------------------+--------------+------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting geolocation → ../delta/bronze/geolocation
# [INFO] Ingested ../data/olist_geolocation_dataset.csv → ../delta/bronze/geolocation
# [INFO] Files written under ../delta/bronze/geolocation:
#    part-00000-37872d5f-2d27-484c-a34f-aa5072016cae-c000.snappy.parquet → 1.01 MB
#    part-00000-6e8094f7-8c1e-40ae-b399-5c51160bed99-c001.snappy.parquet → 0.00 MB
#    part-00001-024ae34c-196a-4fa4-9623-fd8f70036647-c001.snappy.parquet → 0.00 MB
#    part-00001-c1ba2e8b-5884-4af4-b0ca-1e4b358fa724-c000.snappy.parquet → 1.01 MB
#    part-00002-03a14d39-22a2-4ff8-96a2-9e5495e01233-c000.snappy.parquet → 1.02 MB
#    part-00002-98593520-7c90-49e2-a3b5-ff569ed5bcd3-c001.snappy.parquet → 0.00 MB
#    part-00003-13b4afba-4ca3-4ff1-ab83-49082bbb85d6-c000.snappy.parquet → 1.01 MB
#    part-00003-3a43ffab-92b9-4aeb-a436-0308ab206cf0-c001.snappy.parquet → 0.00 MB
#    part-00004-c627bff9-bfde-4f14-8f3c-68d29683c5ca-c000.snappy.parquet → 1.01 MB
#    part-00004-c9259c7f-a062-46c5-afb2-786d303f725b-c001.snappy.parquet → 0.00 MB
#    part-00005-d16d51e9-591f-48d9-a3ea-5ec028e401c2-c001.snappy.parquet → 0.00 MB
#    part-00005-e284f023-63c2-4519-b358-eaf29176b8c5-c000.snappy.parquet → 1.02 MB
#    part-00006-213017db-b403-403c-b63e-8a96f15ca1b4-c000.snappy.parquet → 1.02 MB
#    part-00006-e23b7ff6-d4ef-4987-8c9c-701f4a89ef26-c001.snappy.parquet → 0.00 MB
#    part-00007-0e74cabf-f931-4c92-a02f-c65be4af1b8c-c001.snappy.parquet → 0.00 MB
#    part-00007-9389812f-c8be-4152-9a5e-4860aed731c1-c000.snappy.parquet → 1.02 MB
#    part-00008-1167c5c5-807d-4894-8df1-12ff8a1f3119-c000.snappy.parquet → 1.02 MB
#    part-00008-a8c286bf-daf3-4bd1-9b48-d7aa8c952360-c001.snappy.parquet → 0.00 MB
#    part-00009-343a5183-0c37-419a-8545-450565763850-c001.snappy.parquet → 0.00 MB
#    part-00009-6292476f-5ffd-4558-9908-51c2af5dd52f-c000.snappy.parquet → 1.02 MB
#    part-00010-685a1e4e-35f7-4669-ab99-727d5e1e8a49-c001.snappy.parquet → 0.00 MB
#    part-00010-7c3fe3fc-0927-4798-962b-710e2f2b5400-c000.snappy.parquet → 1.02 MB
#    part-00011-22c3ab6a-595d-4b5a-badb-78fb7855a62a-c001.snappy.parquet → 0.00 MB
#    part-00011-2e62ccc3-9424-4f68-a727-e94ec5415b0b-c000.snappy.parquet → 1.02 MB
#    part-00012-3ad73505-239b-46b3-9848-e91bd1faa8d5-c001.snappy.parquet → 0.00 MB
#    part-00012-f02337cf-2952-4de4-8af1-d90c2ebaca3f-c000.snappy.parquet → 1.01 MB
#    part-00013-0ee2abf4-94f1-47e4-a14d-f4c4eb497c60-c000.snappy.parquet → 1.02 MB
#    part-00013-d56febc4-d416-4d1b-9b2e-943f9d5662ff-c001.snappy.parquet → 0.00 MB
#    part-00014-2d78ef3c-4c17-44cd-9dbb-431c09d9bcb9-c001.snappy.parquet → 0.00 MB
#    part-00014-5f0acf02-d496-4044-bfa3-e717a5bd9306-c000.snappy.parquet → 1.01 MB
#    part-00015-d280575f-566a-44dd-93d8-39ccd893a9d4-c000.snappy.parquet → 1.01 MB
#    part-00015-db33a695-c415-4fd7-aea8-ef6346fca23a-c001.snappy.parquet → 0.00 MB
#    part-00016-1afcf984-a309-47f1-8780-173e06e802d3-c001.snappy.parquet → 0.00 MB
#    part-00016-776e8ce3-8fdb-416d-8423-07f76bb7d4cb-c000.snappy.parquet → 1.02 MB
#    part-00017-2ed1b879-1ed7-45b6-b155-24657c858740-c001.snappy.parquet → 0.00 MB
#    part-00017-b178e5dd-6a30-45a3-9dd2-4fa8aa9fe850-c000.snappy.parquet → 1.02 MB
#    part-00018-559bc5be-23ff-414b-84f4-8ce98ea8661d-c000.snappy.parquet → 1.01 MB
#    part-00018-8bdd81e3-20d6-44d0-bf5f-712c62ff5dcd-c001.snappy.parquet → 0.00 MB
#    part-00019-2fa38af0-c615-42e1-8b01-57a238b6adf7-c000.snappy.parquet → 1.02 MB
#    part-00019-ef7009b1-2e1a-47e1-8f5d-3d745654d72d-c001.snappy.parquet → 0.00 MB
# [INFO] Showing geolocation table (first 5 rows):
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# |geolocation_zip_code_prefix|geolocation_lat    |geolocation_lng    |geolocation_city|geolocation_state|
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# |5417                       |-23.555829363033048|-46.6937886006117  |sao paulo       |SP               |
# |6093                       |-23.53190636724241 |-46.78044929645372 |osasco          |SP               |
# |4082                       |-23.611491428028508|-46.662146352256606|sao paulo       |SP               |
# |1424                       |-23.566898808211686|-46.66251287815227 |são paulo       |SP               |
# |2722                       |-23.499440333546094|-46.676945077784865|sao paulo       |SP               |
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# only showing top 5 rows
#
#
# [INFO] Ingesting category_translation → ../delta/bronze/category_translation
# [INFO] Ingested ../data/product_category_name_translation.csv → ../delta/bronze/category_translation
# [INFO] Files written under ../delta/bronze/category_translation:
#    part-00000-141e0d05-5acb-4f39-bb29-2b1a9ec59984-c000.snappy.parquet → 0.00 MB
#    part-00001-c0d8fc44-960d-41c2-860e-f5a45cec4903-c000.snappy.parquet → 0.00 MB
# [INFO] Showing category_translation table (first 5 rows):
# +---------------------+-----------------------------+
# |product_category_name|product_category_name_english|
# +---------------------+-----------------------------+
# |cama_mesa_banho      |bed_bath_table               |
# |utilidades_domesticas|housewares                   |
# |casa_conforto_2      |home_comfort_2               |
# |cds_dvds_musicais    |cds_dvds_musicals            |
# |artigos_de_festas    |party_supplies               |
# +---------------------+-----------------------------+
# only showing top 5 rows

# %%
print("Bronze layer  ingestion completed successfully!")
# Out:
# Bronze layer  ingestion completed successfully!

# %%
silver_output = "../delta/silver/"

# %%
# Curate Silver Layer
curate_sales(spark, bronze_base=bronze_output, silver_base=silver_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Curate Silver Layer
# ----> 2 curate_sales(spark, bronze_base=bronze_output, silver_base=silver_output)
#
# NameError: name 'bronze_output' is not defined

# %%
# Verify Silver
print("\n[INFO] Silver Layer Sales Table:")
sales_df = spark.read.format("delta").load(f"{silver_output}/sales")
sales_df.show(5, truncate=False)

# %%
sales_df.select("seller_id", "seller_salt").distinct().show(10)

# %%
# Unique city/state samples for customers & sellers
silver_path = "../delta/silver/"
customers_df = spark.read.format("delta").load(silver_path + "customers")
sellers_df = spark.read.format("delta").load(silver_path + "sellers")

print("Customer city samples:", [row.customer_city for row in customers_df.select("customer_city").distinct().limit(5).collect()])
print("Customer state samples:", [row.customer_state for row in customers_df.select("customer_state").distinct().limit(5).collect()])

print("Seller city samples:", [row.seller_city for row in sellers_df.select("seller_city").distinct().limit(5).collect()])
print("Seller state samples:", [row.seller_state for row in sellers_df.select("seller_state").distinct().limit(5).collect()])

# %%
print("Duplicate customers:", customers_df.count() - customers_df.dropDuplicates(["customer_id"]).count())
print("Duplicate sellers:", sellers_df.count() - sellers_df.dropDuplicates(["seller_id"]).count())

# %%
sales_df = spark.read.format("delta").load(silver_path + "sales")

print("Sample seller_id_salted:")
sales_df.select("seller_salt").distinct().show(10, truncate=False)

# %%
spark.stop()
